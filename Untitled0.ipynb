# %%
from google.colab import files
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
url = '/content/drive/MyDrive/KDDcup/kddcup.data_10_percent_corrected'
dataset = pd.read_csv(url)
dataset.head(5)
# Out:
#    0  tcp  http  SF  181  ...  0.00.8  0.00.9  0.00.10  0.00.11  normal.
# 0  0  tcp  http  SF  239  ...     0.0     0.0      0.0      0.0  normal.
# 1  0  tcp  http  SF  235  ...     0.0     0.0      0.0      0.0  normal.
# 2  0  tcp  http  SF  219  ...     0.0     0.0      0.0      0.0  normal.
# 3  0  tcp  http  SF  217  ...     0.0     0.0      0.0      0.0  normal.
# 4  0  tcp  http  SF  217  ...     0.0     0.0      0.0      0.0  normal.
#
# [5 rows x 42 columns]

# %%
dataset['normal.'] = dataset['normal.'].replace(['back.', 'buffer_overflow.', 'ftp_write.', 'guess_passwd.', 'imap.', 'ipsweep.', 'land.', 'loadmodule.', 'multihop.', 'neptune.', 'nmap.', 'perl.', 'phf.', 'pod.', 'portsweep.', 'rootkit.', 'satan.', 'smurf.', 'spy.', 'teardrop.', 'warezclient.', 'warezmaster.'], 'unnormal')

# %%
dataset.shape
# Out:
# (494020, 42)

# %%
le = preprocessing.LabelEncoder()
dataset = dataset.apply(le.fit_transform)
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 41].values
x.shape, y.shape
# Out:
# ((494020, 41), (494020,))

# %%
x = StandardScaler().fit_transform(x)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x)
fadf = pd.DataFrame(data = x_pca
             , columns = ['fa1', 'fa2'])
fadf.head()
# Out:
#         fa1       fa2
# 0  0.677913  1.504438
# 1  0.660825  1.549126
# 2  0.642374  1.524988
# 3  0.618980  1.555335
# 4  0.589030  1.528349

# %%
pd_y = pd.DataFrame(y, columns = ['keadaan'])
pd_y.head(5)
# Out:
#    keadaan
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
finalDf = pd.concat([fadf, pd_y[['keadaan']]], axis = 1)
finalDf.head()
# Out:
#         fa1       fa2  keadaan
# 0  0.677913  1.504438        0
# 1  0.660825  1.549126        0
# 2  0.642374  1.524988        0
# 3  0.618980  1.555335        0
# 4  0.589030  1.528349        0

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal component 1', fontsize = 15)
ax.set_ylabel('principal component 2', fontsize = 15)
ax.set_title('component pca', fontsize = 20)
targets = [0,1]
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['keadaan'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'fa1']
               , finalDf.loc[indicesToKeep, 'fa2']
               , c = color)
ax.legend(['normal','unnormal'])
ax.grid()

# %% [markdown]
# # data Pca diubah menjadi x dan y

# %%
dataset_clas1 = finalDf
y_clas1 = dataset_clas1['keadaan']
x_clas1 = dataset_clas1.drop(['keadaan'], axis=1)

print ("dataset : ",dataset_clas1.shape)
print ("x : ",x_clas1.shape)
print ("y : ",y_clas1.shape)
# Out:
# dataset :  (494020, 3)
# x :  (494020, 2)
# y :  (494020,)

# %% [markdown]
# # merubah dataset menjadi data train dan data test

# %%
X_train, X_test, y_train, y_test = train_test_split(x_clas1, y_clas1, test_size = 0.2, random_state = 42)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
hasil = classifier.fit(X_train, y_train)

# Predicting the Test set results
predictions = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predictions)

from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
print('accuracy is ',accuracy_score(predictions,y_test))
# Out:
# [[11548  7820]
#  [  574 78862]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.60      0.73     19368
#            1       0.91      0.99      0.95     79436
#
#     accuracy                           0.92     98804
#    macro avg       0.93      0.79      0.84     98804
# weighted avg       0.92      0.92      0.91     98804
#
# accuracy is  0.915043925347152
